# %%
print('Hello')
# Out:
# Hello

# %%
a = 3
b = 10
a+b
# Out:
# 13

# %%
c = 'amount'
d = a + b
print(c, d)
# Out:
# amount 13

# %%
f = 'My name is Hanna,'
g = 'i am learning coding'

# %%
print( f, g)
# Out:
# My name is Hanna, i am learning coding

# %%
f, g
# Out:
# ('My name is Hanna', 'i am learning coding')

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(np.sin(range(50)))

# %% [markdown]
# # Розділ 1
# ## Підрозділ
# ### Заголовок
